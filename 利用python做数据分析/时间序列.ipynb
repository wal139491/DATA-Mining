# %%
import pandas as pd
from pandas import Series,DataFrame
import numpy as np

# %%
p = pd.Period('2016Q4', freq='Q-JAN')
p
# Out:
# Period('2016Q4', 'Q-JAN')

# %%
p.asfreq('D', how='start')
# Out:
# Period('2015-11-01', 'D')

# %%
pd.date_range(start='1/3/2016 23:59', periods=10,freq='M')
# Out:
# DatetimeIndex(['2016-01-31 23:59:00', '2016-02-29 23:59:00',
#                '2016-03-31 23:59:00', '2016-04-30 23:59:00',
#                '2016-05-31 23:59:00', '2016-06-30 23:59:00',
#                '2016-07-31 23:59:00', '2016-08-31 23:59:00',
#                '2016-09-30 23:59:00', '2016-10-31 23:59:00'],
#               dtype='datetime64[ns]', freq='M')

# %%
p4pm = (p.asfreq('B','e')-1).asfreq('H','s')+16

# %%
p4pm
# Out:
# Period('2016-01-28 16:00', 'H')

# %%
p4pm.to_timestamp()
# Out:
# Timestamp('2016-01-28 16:00:00')

# %%
rng = pd.period_range('2016Q3','2017Q4', freq='Q-JAN')

# %%
ts = Series(np.arange(len(rng)), index=rng)

# %%
ts
# Out:
# 2016Q3    0
# 2016Q4    1
# 2017Q1    2
# 2017Q2    3
# 2017Q3    4
# 2017Q4    5
# Freq: Q-JAN, dtype: int32

# %%
new_rng = (rng.asfreq('B','e')-1).asfreq('T','s')+16*60

# %%
new_rng
# Out:
# PeriodIndex(['2015-10-29 16:00', '2016-01-28 16:00', '2016-04-28 16:00',
#              '2016-07-28 16:00', '2016-10-28 16:00', '2017-01-30 16:00'],
#             dtype='int64', freq='T')

# %%
rng = pd.date_range('1/1/2000',periods=3,freq='M')

# %%
ts = Series(np.random.rand(3),index= rng)

# %%
ps = ts.to_period()

# %%
ps
# Out:
# 2000-01    0.175953
# 2000-02    0.292211
# 2000-03    0.787191
# Freq: M, dtype: float64

# %%
rng1 = pd.date_range('1/29/2017', periods=6, freq='T')

# %%
ts2 = Series(np.random.randn(6),index=rng1)

# %%
type(ts2)
# Out:
# pandas.core.series.Series

# %%
ps = ts2.to_period()
ps
# Out:
# 2017-01-29 00:00    0.002131
# 2017-01-29 00:01   -1.444521
# 2017-01-29 00:02    0.163287
# 2017-01-29 00:03   -0.421580
# 2017-01-29 00:04    0.595571
# 2017-01-29 00:05    0.211020
# Freq: T, dtype: float64

# %%
type(ps)
# Out:
# pandas.core.series.Series

# %%
ps.to_timestamp()
# Out:
# 2017-01-29 00:00:00    0.002131
# 2017-01-29 00:01:00   -1.444521
# 2017-01-29 00:02:00    0.163287
# 2017-01-29 00:03:00   -0.421580
# 2017-01-29 00:04:00    0.595571
# 2017-01-29 00:05:00    0.211020
# Freq: T, dtype: float64

# %%
type(ps)
# Out:
# pandas.core.series.Series

# %%
datas =pd.read_csv("F:\数据挖掘\pydata-book\ch08\macrodata.csv")

# %%
datas.columns
# Out:
# Index(['year', 'quarter', 'realgdp', 'realcons', 'realinv', 'realgovt',
#        'realdpi', 'cpi', 'm1', 'tbilrate', 'unemp', 'pop', 'infl', 'realint'],
#       dtype='object')

# %%
datas.columns.shape
# Out:
# (14,)

# %%
datas.index.shape
# Out:
# (203,)

# %%
datas
# Out:
#        year  quarter    realgdp  realcons   realinv  realgovt  realdpi  \
# 0    1959.0      1.0   2710.349    1707.4   286.898   470.045   1886.9
# 1    1959.0      2.0   2778.801    1733.7   310.859   481.301   1919.7
# 2    1959.0      3.0   2775.488    1751.8   289.226   491.260   1916.4
# 3    1959.0      4.0   2785.204    1753.7   299.356   484.052   1931.3
# 4    1960.0      1.0   2847.699    1770.5   331.722   462.199   1955.5
# 5    1960.0      2.0   2834.390    1792.9   298.152   460.400   1966.1
# 6    1960.0      3.0   2839.022    1785.8   296.375   474.676   1967.8
# 7    1960.0      4.0   2802.616    1788.2   259.764   476.434   1966.6
# 8    1961.0      1.0   2819.264    1787.7   266.405   475.854   1984.5
# 9    1961.0      2.0   2872.005    1814.3   286.246   480.328   2014.4
# 10   1961.0      3.0   2918.419    1823.1   310.227   493.828   2041.9
# 11   1961.0      4.0   2977.830    1859.6   315.463   502.521   2082.0
# ...

# %%
pd.PeriodIndex(year=datas.year, quarter=datas.quarter,freq='Q-DEC')
# Out:
# PeriodIndex(['1959Q1', '1959Q2', '1959Q3', '1959Q4', '1960Q1', '1960Q2',
#              '1960Q3', '1960Q4', '1961Q1', '1961Q2',
#              ...
#              '2007Q2', '2007Q3', '2007Q4', '2008Q1', '2008Q2', '2008Q3',
#              '2008Q4', '2009Q1', '2009Q2', '2009Q3'],
#             dtype='int64', length=203, freq='Q-DEC')

# %%
index1 = pd.PeriodIndex()
