# %%
import os
import json

path = r'F:\数据挖掘\pydata-book\ch02\usagov_bitly_data2012-03-16-1331923249.txt'
records = [json.loads(file) for file in open(path)]
# open(path)产生一个文件对象
# 每行为一个字典，records是字典组成的序列

# %%
records[0]
# Out:
# {'a': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.78 Safari/535.11',
#  'al': 'en-US,en;q=0.8',
#  'c': 'US',
#  'cy': 'Danvers',
#  'g': 'A6qOVH',
#  'gr': 'MA',
#  'h': 'wfLQtf',
#  'hc': 1331822918,
#  'hh': '1.usa.gov',
#  'l': 'orofrog',
#  'll': [42.576698, -70.954903],
#  'nk': 1,
#  'r': 'http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/wfLQtf',
#  't': 1331923247,
#  'tz': 'America/New_York',
#  'u': 'http://www.ncbi.nlm.nih.gov/pubmed/22415991'}

# %%
from pandas import  DataFrame,Series
import pandas as pd
import numpy as np

df = DataFrame(records)
df
# Out:
#        _heartbeat_                                                  a  \
# 0              NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1              NaN                             GoogleMaps/RochesterNY
# 2              NaN  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 3              NaN  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 4              NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 5              NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 6              NaN  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...
# 7              NaN  Mozilla/5.0 (Windows NT 6.1; rv:2.0.1) Gecko/2...
# 8              NaN  Opera/9.80 (X11; Linux zbov; U; en) Presto/2.1...
# 9              NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 10             NaN  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2)...
# 11             NaN  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.4...
# ...

# %%
df['tz'][:10]
# Out:
# 0     America/New_York
# 1       America/Denver
# 2     America/New_York
# 3    America/Sao_Paulo
# 4     America/New_York
# 5     America/New_York
# 6        Europe/Warsaw
# 7
# 8
# 9
# Name: tz, dtype: object

# %%
df['tz'].head()
# Out:
# 0     America/New_York
# 1       America/Denver
# 2     America/New_York
# 3    America/Sao_Paulo
# 4     America/New_York
# Name: tz, dtype: object

# %%
tz_counts = df['tz'].value_counts()
tz_counts[0:10]
# Out:
# America/New_York       1251
#                         521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# America/Sao_Paulo        33
# Name: tz, dtype: int64

# %%
clean_tz = df['tz'].fillna('Missing')
clean_tz[clean_tz == ''] = 'Unknow'
tz_xconuts = clean_tz.value_counts()
tz_xconuts[:10]
# Out:
# America/New_York       1251
# Unknow                  521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# Missing                 120
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# Name: tz, dtype: int64

# %%
# %matplotlib inline
tz_xconuts[:10].plot(kind='barh', rot=0)
# 统计usa.gov最常出现的时区

# %%
results = Series([x.split()[0] for x in df.a.dropna()])
# 去除a列中缺失值，缺失跟空值不一样，在组成一个新的列表赋给series
# 再截取分割后的第一部分
results[:5]
# Out:
# 0               Mozilla/5.0
# 1    GoogleMaps/RochesterNY
# 2               Mozilla/4.0
# 3               Mozilla/5.0
# 4               Mozilla/5.0
# dtype: object

# %%
results.value_counts()[:8]
# value_counts对result这一列进行统计
# Out:
# Mozilla/5.0                 2594
# Mozilla/4.0                  601
# GoogleMaps/RochesterNY       121
# Opera/9.80                    34
# TEST_INTERNET_AGENT           24
# GoogleProducer                21
# Mozilla/6.0                    5
# BlackBerry8520/5.0.0.681       4
# dtype: int64

# %%
import re
# 将a列值为空的数据删除
cdf = df[df.a.notnull()]
operating_system = np.where(cdf.a.str.contains('Windows'),'Windows','Not Windows')
operating_system[:5]
# Out:
# array(['Windows', 'Not Windows', 'Windows', 'Not Windows', 'Windows'],
#       dtype='<U11')

# %%
print(type(operating_system))
# Out:
# <class 'numpy.ndarray'>

# %%
# 按照时区和新得到的操作系统进行分组
by_tz_os = cdf.groupby(['tz', operating_system])

# %%
agg_counts = by_tz_os.size().fillna(0)
agg_counts[:10]
# Out:
# tz
#                                 Not Windows    245
#                                 Windows        276
# Africa/Cairo                    Windows          3
# Africa/Casablanca               Windows          1
# Africa/Ceuta                    Windows          2
# Africa/Johannesburg             Windows          1
# Africa/Lusaka                   Windows          1
# America/Anchorage               Not Windows      4
#                                 Windows          1
# America/Argentina/Buenos_Aires  Not Windows      1
# dtype: int64

# %%
agg_counts = by_tz_os.size().unstack().fillna(0)
# 利用size对分组结果计数，再利用unstack对计数结果进行重塑
# 与上面比较下差异
agg_counts[:10]
# Out:
#                                 Not Windows  Windows
# tz
#                                       245.0    276.0
# Africa/Cairo                            0.0      3.0
# Africa/Casablanca                       0.0      1.0
# Africa/Ceuta                            0.0      2.0
# Africa/Johannesburg                     0.0      1.0
# Africa/Lusaka                           0.0      1.0
# America/Anchorage                       4.0      1.0
# America/Argentina/Buenos_Aires          1.0      0.0
# America/Argentina/Cordoba               0.0      1.0
# America/Argentina/Mendoza               0.0      1.0

# %%
print(type(by_tz_os))
# Out:
# <class 'pandas.core.groupby.DataFrameGroupBy'>

# %%
agg_counts.columns
# Out:
# Index(['Not Windows', 'Windows'], dtype='object')

# %%
# 利用行数构建了一个间接的索引
indexer = agg_counts.sum(1).argsort()
# 升序排列
indexer[:10]
# Out:
# tz
#                                   24
# Africa/Cairo                      20
# Africa/Casablanca                 21
# Africa/Ceuta                      92
# Africa/Johannesburg               87
# Africa/Lusaka                     53
# America/Anchorage                 54
# America/Argentina/Buenos_Aires    57
# America/Argentina/Cordoba         26
# America/Argentina/Mendoza         55
# dtype: int64

# %%
count_subset =agg_counts.take(indexer)[-10:]
count_subset
# Out:
#                      Not Windows  Windows
# tz
# America/Sao_Paulo           13.0     20.0
# Europe/Madrid               16.0     19.0
# Pacific/Honolulu             0.0     36.0
# Asia/Tokyo                   2.0     35.0
# Europe/London               43.0     31.0
# America/Denver             132.0     59.0
# America/Los_Angeles        130.0    252.0
# America/Chicago            115.0    285.0
#                            245.0    276.0
# America/New_York           339.0    912.0

# %%
nurmed_subset = count_subset.div(count_subset.sum(1), axis=0)
nurmed_subset.plot(kind ='barh', stacked=True)
# 这个总计为1，显示的比较明显

# %% [markdown]
# ## MovieLens 1M数据集

# %%
import pandas as pd

unames = ['user_id', 'gender', 'age' , 'occupation', 'zip']
users = pd.read_table(r'F:\数据挖掘\pydata-book\ch02\movielens\users.dat', sep='::', header=None, names=unames)

rnames = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings = pd.read_table(r'F:\数据挖掘\pydata-book\ch02\movielens\ratings.dat', sep='::', header=None, names=rnames)

mnames  = ['movie_id', 'title', 'geners']
movies = pd.read_table(r'F:\数据挖掘\pydata-book\ch02\movielens\movies.dat', sep='::', header=None, names=mnames)
# Out:
# F:\Anaconda\lib\site-packages\ipykernel\__main__.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
# F:\Anaconda\lib\site-packages\ipykernel\__main__.py:7: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
# F:\Anaconda\lib\site-packages\ipykernel\__main__.py:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
data = pd.merge(pd.merge(ratings, users), movies)
# merge根据列名重叠情况，推断那些列是合并的

# %%
data
# Out:
#          user_id  movie_id  rating   timestamp gender  age  occupation    zip  \
# 0              1      1193       5   978300760      F    1          10  48067
# 1              2      1193       5   978298413      M   56          16  70072
# 2             12      1193       4   978220179      M   25          12  32793
# 3             15      1193       4   978199279      M   25           7  22903
# 4             17      1193       5   978158471      M   50           1  95350
# 5             18      1193       4   978156168      F   18           3  95825
# 6             19      1193       5   982730936      M    1          10  48073
# 7             24      1193       5   978136709      F   25           7  10023
# 8             28      1193       3   978125194      F   25           1  14607
# 9             33      1193       5   978557765      M   45           3  55421
# 10            39      1193       5   978043535      M   18           4  61820
# ...

# %%
data.ix[0]
# Out:
# user_id                                            1
# movie_id                                        1193
# rating                                             5
# timestamp                                  978300760
# gender                                             F
# age                                                1
# occupation                                        10
# zip                                            48067
# title         One Flew Over the Cuckoo's Nest (1975)
# geners                                         Drama
# Name: 0, dtype: object

# %%
mean_ratings = data.pivot_table('rating', index='title', columns  = 'gender', aggfunc='mean')
# 产生一个DataFrame,行为电影名称，列为性别，内容是电影平均得分
# female male

# %%
mean_ratings[:5]
# Out:
# gender                                F         M
# title
# $1,000,000 Duck (1971)         3.375000  2.761905
# 'Night Mother (1986)           3.388889  3.352941
# 'Til There Was You (1997)      2.675676  2.733333
# 'burbs, The (1989)             2.793478  2.962085
# ...And Justice for All (1979)  3.828571  3.689024

# %%
# 先过滤掉评论不足250条的电影
# 按照电影名称进行分组，在用size对分组进行计数

ratings_by_title = data.groupby('title').size()
# 利用size得到一个含有各电影分组大小的Series对象
ratings_by_title[:10]
# Out:
# title
# $1,000,000 Duck (1971)                37
# 'Night Mother (1986)                  70
# 'Til There Was You (1997)             52
# 'burbs, The (1989)                   303
# ...And Justice for All (1979)        199
# 1-900 (1994)                           2
# 10 Things I Hate About You (1999)    700
# 101 Dalmatians (1961)                565
# 101 Dalmatians (1996)                364
# 12 Angry Men (1957)                  616
# dtype: int64

# %%
active_titles = ratings_by_title.index[ratings_by_title >= 250]

# %%
active_titles
# 得到评论数大于250的索引，这些索引的名称是电影名，因为上面是按电影名进行分组的
# Out:
# Index([''burbs, The (1989)', '10 Things I Hate About You (1999)',
#        '101 Dalmatians (1961)', '101 Dalmatians (1996)', '12 Angry Men (1957)',
#        '13th Warrior, The (1999)', '2 Days in the Valley (1996)',
#        '20,000 Leagues Under the Sea (1954)', '2001: A Space Odyssey (1968)',
#        '2010 (1984)',
#        ...
#        'X-Men (2000)', 'Year of Living Dangerously (1982)',
#        'Yellow Submarine (1968)', 'You've Got Mail (1998)',
#        'Young Frankenstein (1974)', 'Young Guns (1988)',
#        'Young Guns II (1990)', 'Young Sherlock Holmes (1985)',
#        'Zero Effect (1998)', 'eXistenZ (1999)'],
#       dtype='object', name='title', length=1216)

# %%
# 根据上面索引，从mean_rating选取需要的行
mean_ratings = mean_ratings.ix[active_titles]

# %%
mean_ratings.head()
# 获取评论大于250，然后根据性别计算每个电影的平均得分
# Out:
# gender                                    F         M
# title
# 'burbs, The (1989)                 2.793478  2.962085
# 10 Things I Hate About You (1999)  3.646552  3.311966
# 101 Dalmatians (1961)              3.791444  3.500000
# 101 Dalmatians (1996)              3.240000  2.911215
# 12 Angry Men (1957)                4.184397  4.328421

# %%
# 为了了解女性观众最喜欢的电影，按降序排列
top_female_movies = mean_ratings.sort_values(by='F', ascending=False)
top_female_movies[:10]
# Out:
# gender                                                     F         M
# title
# Close Shave, A (1995)                               4.644444  4.473795
# Wrong Trousers, The (1993)                          4.588235  4.478261
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)       4.572650  4.464589
# Wallace & Gromit: The Best of Aardman Animation...  4.563107  4.385075
# Schindler's List (1993)                             4.562602  4.491415
# Shawshank Redemption, The (1994)                    4.539075  4.560625
# Grand Day Out, A (1992)                             4.537879  4.293255
# To Kill a Mockingbird (1962)                        4.536667  4.372611
# Creature Comforts (1990)                            4.513889  4.272277
# Usual Suspects, The (1995)                          4.513317  4.518248

# %%
top_male_movies = mean_ratings.sort_values(by = 'M', ascending=False)
top_male_movies[:10]
# Out:
# gender                                                     F         M
# title
# Godfather, The (1972)                               4.314700  4.583333
# Seven Samurai (The Magnificent Seven) (Shichini...  4.481132  4.576628
# Shawshank Redemption, The (1994)                    4.539075  4.560625
# Raiders of the Lost Ark (1981)                      4.332168  4.520597
# Usual Suspects, The (1995)                          4.513317  4.518248
# Star Wars: Episode IV - A New Hope (1977)           4.302937  4.495307
# Schindler's List (1993)                             4.562602  4.491415
# Wrong Trousers, The (1993)                          4.588235  4.478261
# Close Shave, A (1995)                               4.644444  4.473795
# Rear Window (1954)                                  4.484536  4.472991

# %% [markdown]
# ### 计算平均分歧
# 想找出男女分歧最大的电影，
# 1. mean_ratings增加一个男女电影评分之差的列
# 2. 对这个列进行排序

# %%
mean_ratings['diff'] = mean_ratings['M'] - mean_ratings['F']
sort_by_diff = mean_ratings.sort_values(by = 'diff')

# %%
sort_by_diff[:15]
# Out:
# gender                                        F         M      diff
# title
# Dirty Dancing (1987)                   3.790378  2.959596 -0.830782
# Jumpin' Jack Flash (1986)              3.254717  2.578358 -0.676359
# Grease (1978)                          3.975265  3.367041 -0.608224
# Little Women (1994)                    3.870588  3.321739 -0.548849
# Steel Magnolias (1989)                 3.901734  3.365957 -0.535777
# Anastasia (1997)                       3.800000  3.281609 -0.518391
# Rocky Horror Picture Show, The (1975)  3.673016  3.160131 -0.512885
# Color Purple, The (1985)               4.158192  3.659341 -0.498851
# Age of Innocence, The (1993)           3.827068  3.339506 -0.487561
# Free Willy (1993)                      2.921348  2.438776 -0.482573
# French Kiss (1995)                     3.535714  3.056962 -0.478752
# Little Shop of Horrors, The (1960)     3.650000  3.179688 -0.470312
# Guys and Dolls (1955)                  4.051724  3.583333 -0.468391
# ...

# %%
# 对sort_by_diff取反序就得到男性最喜欢的电影
sort_by_diff[::-1][:15]
# [::-1] 因为有三列数据，就对最后一列进行反序，在切片得到前15行数据
# Out:
# gender                                         F         M      diff
# title
# Good, The Bad and The Ugly, The (1966)  3.494949  4.221300  0.726351
# Kentucky Fried Movie, The (1977)        2.878788  3.555147  0.676359
# Dumb & Dumber (1994)                    2.697987  3.336595  0.638608
# Longest Day, The (1962)                 3.411765  4.031447  0.619682
# Cable Guy, The (1996)                   2.250000  2.863787  0.613787
# Evil Dead II (Dead By Dawn) (1987)      3.297297  3.909283  0.611985
# Hidden, The (1987)                      3.137931  3.745098  0.607167
# Rocky III (1982)                        2.361702  2.943503  0.581801
# Caddyshack (1980)                       3.396135  3.969737  0.573602
# For a Few Dollars More (1965)           3.409091  3.953795  0.544704
# Porky's (1981)                          2.296875  2.836364  0.539489
# Animal House (1978)                     3.628906  4.167192  0.538286
# ...

# %%
# 根据电影名称分组的得分数据的标准差
rating_std_by_title = data.groupby('title')['rating'].std()
print(type(rating_std_by_title))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# 根据active_title进行过滤
rating_std_by_title = rating_std_by_title.ix[active_titles]

# %%
# 根据值对Series进行降序排列
rating_std_by_title.sort_values(ascending=False)[:10]
# Out:
# title
# Foreign Student (1994)                                             2.828427
# Criminal Lovers (Les Amants Criminels) (1999)                      2.309401
# Identification of a Woman (Identificazione di una donna) (1982)    2.121320
# Sunset Park (1996)                                                 2.121320
# Eaten Alive (1976)                                                 2.121320
# Neon Bible, The (1995)                                             2.121320
# Talk of Angels (1998)                                              2.121320
# Tokyo Fist (1995)                                                  2.121320
# Paralyzing Fear: The Story of Polio in America, A (1998)           2.121320
# Better Living (1998)                                               2.121320
# Name: rating, dtype: float64

# %% [markdown]
# ## 1880-2010 全美婴儿的姓名
# 一般用这个数据集进行R包的演示
#
# 可以用这个数据集做什么呢：
# 1. 计算某个姓名的年度比例
# 2. 计算某个名字的排名
# 3. 计算各年度最流行的名字，以及增长最快增长最慢的名字
# 4. 预测名字的趋势： 元音、长度、首字母、拼写变化等
# 5. 分析外源姓的趋势
#
# >1. 数据挖掘,使用工具挖掘分析数据，找出有价值的话题，研究它
# >2. 机器学习，将无序的海量数据转换成有用的信息（最终目的是从数据集中受到启发，挖掘数据背后的真实含义）垃圾邮件 推荐系统 人脸识别
# >3. 理解数据、处理数据、从中抽取价值，展示和交流数据结果

# %%
import pandas as pd
names1880 = pd.read_csv(r'F:\数据挖掘\pydata-book\ch02\names\yob1880.txt', names=['name', 'sex', 'births'])

# %%
names1880.head()
# Out:
#         name sex  births
# 0       Mary   F    7065
# 1       Anna   F    2604
# 2       Emma   F    2003
# 3  Elizabeth   F    1939
# 4     Minnie   F    1746

# %%
names1880.columns
# Out:
# Index(['name', 'sex', 'births'], dtype='object')

# %%
names1880.groupby('sex').births.sum()
# Out:
# sex
# F     90993
# M    110493
# Name: births, dtype: int64

# %%
news

# %%
#  拼接合并1880-2010数据集

years = range(1880,2011)

for year in years:
    path = r'F:\数据挖掘\pydata-book\ch02\names\%d.txt' %year
